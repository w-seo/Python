# %% [markdown]
# <a href="https://colab.research.google.com/github/Woobin-Seo/Python/blob/master/object_detection/image_data_create.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install icrawler
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/62/00/ee1d7de624db8ba7090d1226aebefab96a2c71cd5cfa7629d6ad3f61b79e/urllib3-1.24.1-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl
# ...

# %%
from icrawler.builtin import GoogleImageCrawler

# %%
# 猫の画像を100枚取得
crawler = GoogleImageCrawler(storage={"root_dir": "cats"})
crawler.crawl(keyword="猫", max_num=100)
# Out:
# 2019-01-11 15:46:22,697 - INFO - icrawler.crawler - start crawling...
# 2019-01-11 15:46:22,699 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2019-01-11 15:46:22,711 - INFO - feeder - thread feeder-001 exit
# 2019-01-11 15:46:22,728 - INFO - icrawler.crawler - starting 1 parser threads...
# 2019-01-11 15:46:22,736 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2019-01-11 15:46:23,831 - INFO - parser - parsing result page https://www.google.com/search?q=%E7%8C%AB&ijn=0&start=0&tbs=&tbm=isch
# 2019-01-11 15:46:24,405 - INFO - downloader - image #1	https://upload.wikimedia.org/wikipedia/commons/thumb/9/9e/2016-06-14_Orange_and_white_tabby_cat_born_in_2016_%E8%8C%B6%E3%83%88%E3%83%A9%E7%99%BD%E3%81%AD%E3%81%93_DSCF6526%E2%98%86%E5%BD%A1.jpg/200px-2016-06-14_Orange_and_white_tabby_cat_born_in_2016_%E8%8C%B6%E3%83%88%E3%83%A9%E7%99%BD%E3%81%AD%E3%81%93_DSCF6526%E2%98%86%E5%BD%A1.jpg
# ...

# %%
#ライオンの画像を100枚取得
crawler = GoogleImageCrawler(storage={"root_dir": "lions"})
crawler.crawl(keyword="ライオン", max_num=100)
# Out:
# 2019-01-11 15:48:50,813 - INFO - icrawler.crawler - start crawling...
# 2019-01-11 15:48:50,818 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2019-01-11 15:48:50,824 - INFO - feeder - thread feeder-001 exit
# 2019-01-11 15:48:50,836 - INFO - icrawler.crawler - starting 1 parser threads...
# 2019-01-11 15:48:50,845 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2019-01-11 15:48:51,268 - INFO - parser - parsing result page https://www.google.com/search?q=%E3%83%A9%E3%82%A4%E3%82%AA%E3%83%B3&ijn=0&start=0&tbs=&tbm=isch
# 2019-01-11 15:48:51,400 - INFO - downloader - image #1	http://www.aws-s.com/getImage.php?path=eve021_l1.jpg
# 2019-01-11 15:48:51,784 - INFO - downloader - image #2	http://www.africansafari.co.jp/park_info/img/animal/s2-photo-1-1.jpg
# 2019-01-11 15:48:51,863 - INFO - downloader - image #3	https://www.city.chiba.jp/zoo/zone/images/img5206.jpg
# ...

# %%
from IPython.display import Image, display_jpeg

# %%
#ライオンの画像を表示
display_jpeg(Image("./lions/000001.jpg"))
