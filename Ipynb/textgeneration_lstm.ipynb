# %%
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import Dense, Activation, LSTM

# %%
from keras.optimizers import RMSprop

# %%
from keras.utils.data_utils import get_file

# %%
import numpy as np

# %%
import random

# %%
import sys

# %%
path = './kanashiki_joo.txt'

# %%
bindata = open(path, "rb").read()

# %%
text = bindata.decode("shift_jis")

# %%
print('Size of text: ', len(text))
# Out:
# Size of text:  4293

# %%
chars = sorted(list(set(text)))

# %%
print('Total chars:', len(chars))
# Out:
# Total chars: 526

# %%
char_indices = dict((c, i) for i, c in enumerate(chars))

# %%
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
maxlen = 40

# %%
step = 3

# %%
sentences = []
next_chars = []

# %%
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

# %%
print('Number of sentences: ', len(sentences))
# Out:
# Number of sentences:  1418

# %%
#　テキストのベクトル化

# %%
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)

# %%
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
# モデルを定義する

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))

# %%
model.add(Dense(len(chars)))

# %%
model.add(Activation('softmax'))

# %%
optimizer = RMSprop(lr=0.01)

# %%
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.array(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('繰り返し回数: ', iteration)
    model.fit(X, y, batch_size=128, epochs=1)
    
start_index = random.randint(0, len(text)-maxlen-1)

for diversity in [0.2, 0.5, 1.0, 1.2]:
    print()
    print('-----diversity', diversity)
    
    generated = ''
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    print('-----Seedを生成しました: ' + sentence + '"')
    sys.stdout.write(generated)
    
    for i in range(400):
        x = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x[0, t, char_indices[char]] = 1.
        
        preds = model.predict(x, verbose=9)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]
        
        generated += next_char
        sentence = sentence[1:] + next_char
        
        sys.stdout.write(next_char)
        sys.stdout.flush()
    
    print()
# Out:
# --------------------------------------------------
# 繰り返し回数:  1
# Epoch 1/1
# 1418/1418 [==============================] - 4s 2ms/step - loss: 0.0040
#
# --------------------------------------------------
# 繰り返し回数:  2
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 7.4502e-04
#
# --------------------------------------------------
# 繰り返し回数:  3
# Epoch 1/1
# 1418/1418 [==============================] - 4s 2ms/step - loss: 2.5739e-04
#
# --------------------------------------------------
# 繰り返し回数:  4
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 1.6310e-04
#
# --------------------------------------------------
# 繰り返し回数:  5
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 1.0733e-04
#
# --------------------------------------------------
# 繰り返し回数:  6
# Epoch 1/1
# 1418/1418 [==============================] - 4s 3ms/step - loss: 7.2725e-05
#
# --------------------------------------------------
# 繰り返し回数:  7
# Epoch 1/1
# 1418/1418 [==============================] - 4s 3ms/step - loss: 4.6277e-05
#
# --------------------------------------------------
# 繰り返し回数:  8
# Epoch 1/1
# 1418/1418 [==============================] - 4s 3ms/step - loss: 0.0177
#
# --------------------------------------------------
# 繰り返し回数:  9
# Epoch 1/1
# 1418/1418 [==============================] - 4s 3ms/step - loss: 0.0473
#
# --------------------------------------------------
# 繰り返し回数:  10
# Epoch 1/1
# 1418/1418 [==============================] - 4s 3ms/step - loss: 0.0130
#
# --------------------------------------------------
# 繰り返し回数:  11
# Epoch 1/1
# 1418/1418 [==============================] - 4s 3ms/step - loss: 0.0105
#
# --------------------------------------------------
# 繰り返し回数:  12
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0090
#
# --------------------------------------------------
# 繰り返し回数:  13
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0011
#
# --------------------------------------------------
# 繰り返し回数:  14
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 4.6331e-04
#
# --------------------------------------------------
# 繰り返し回数:  15
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 2.8945e-04
#
# --------------------------------------------------
# 繰り返し回数:  16
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 1.5680e-04
#
# --------------------------------------------------
# 繰り返し回数:  17
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 7.2766e-05
#
# --------------------------------------------------
# 繰り返し回数:  18
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 4.7687e-05
#
# --------------------------------------------------
# 繰り返し回数:  19
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 3.1090e-05
#
# --------------------------------------------------
# 繰り返し回数:  20
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 2.0015e-05
#
# --------------------------------------------------
# 繰り返し回数:  21
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 1.4083e-05
#
# --------------------------------------------------
# 繰り返し回数:  22
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 8.4450e-06
#
# --------------------------------------------------
# 繰り返し回数:  23
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 6.0834e-06
#
# --------------------------------------------------
# 繰り返し回数:  24
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 3.4571e-06
#
# --------------------------------------------------
# 繰り返し回数:  25
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0295
#
# --------------------------------------------------
# 繰り返し回数:  26
# Epoch 1/1
# 1418/1418 [==============================] - 4s 3ms/step - loss: 0.0401
#
# --------------------------------------------------
# 繰り返し回数:  27
# Epoch 1/1
# 1418/1418 [==============================] - 4s 3ms/step - loss: 0.0017
#
# --------------------------------------------------
# 繰り返し回数:  28
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 3.7002e-04
#
# --------------------------------------------------
# 繰り返し回数:  29
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 2.2181e-04
#
# --------------------------------------------------
# 繰り返し回数:  30
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 1.4956e-04
#
# --------------------------------------------------
# 繰り返し回数:  31
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 1.0120e-04
#
# --------------------------------------------------
# 繰り返し回数:  32
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 6.9324e-05
#
# --------------------------------------------------
# 繰り返し回数:  33
# Epoch 1/1
# 1418/1418 [==============================] - 4s 3ms/step - loss: 4.5529e-05
#
# --------------------------------------------------
# 繰り返し回数:  34
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 3.1626e-05
#
# --------------------------------------------------
# 繰り返し回数:  35
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 2.0279e-05
#
# --------------------------------------------------
# 繰り返し回数:  36
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 1.3126e-05
#
# --------------------------------------------------
# 繰り返し回数:  37
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 2.2402e-05
#
# --------------------------------------------------
# 繰り返し回数:  38
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0355
#
# --------------------------------------------------
# 繰り返し回数:  39
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0202
#
# --------------------------------------------------
# 繰り返し回数:  40
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0165
#
# --------------------------------------------------
# 繰り返し回数:  41
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0015
#
# --------------------------------------------------
# 繰り返し回数:  42
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 3.7281e-04
#
# --------------------------------------------------
# 繰り返し回数:  43
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 2.0951e-04
#
# --------------------------------------------------
# 繰り返し回数:  44
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 1.3692e-04
#
# --------------------------------------------------
# 繰り返し回数:  45
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 9.2726e-05
#
# --------------------------------------------------
# 繰り返し回数:  46
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 6.0460e-05
#
# --------------------------------------------------
# 繰り返し回数:  47
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 3.8827e-05
#
# --------------------------------------------------
# 繰り返し回数:  48
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 2.7028e-05
#
# --------------------------------------------------
# 繰り返し回数:  49
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 1.8456e-05
#
# --------------------------------------------------
# 繰り返し回数:  50
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0326
#
# --------------------------------------------------
# 繰り返し回数:  51
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0369
#
# --------------------------------------------------
# 繰り返し回数:  52
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0201
#
# --------------------------------------------------
# 繰り返し回数:  53
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0202
#
# --------------------------------------------------
# 繰り返し回数:  54
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0061
#
# --------------------------------------------------
# 繰り返し回数:  55
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0080
#
# --------------------------------------------------
# 繰り返し回数:  56
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0101
#
# --------------------------------------------------
# 繰り返し回数:  57
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 0.0036
#
# --------------------------------------------------
# 繰り返し回数:  58
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 5.0725e-04
#
# --------------------------------------------------
# 繰り返し回数:  59
# Epoch 1/1
# 1418/1418 [==============================] - 3s 2ms/step - loss: 1.2021e-04
#
# -----diversity 0.2
# -----Seedを生成しました: 巻いて、赤く染めた牝牛の皮で足を包んでいた。
# 　女の顔は蝋のように蒼白く、この"
# 巻いて、赤く染めた牝牛の皮で足を包んでいた。
# 　女の顔は蝋のように蒼白く、この世のうに蒼しさ、ともあった、水はげら息とびった。スカァアは砂に十にを乗て組まその素の歌を見た。
# 　彼等を見ていた。
# 　彼等たこの歌をた。
# 　彼等た二人の互に彼女の上に光った。二人の鳥んたのように黒いよりも先ように黒いたとないた、死人の沈沈み、海を砂いっていって、槍かないた。
# 　多うは二人の女は暗っをの上に彼ら一人の女が暗った。二人の女は二人のを沈ていた。
# 　彼は死ぬ前のこうに彼女の長い息い槍となっていってしく、槍とな、まった。
# 　ウうただ高は死人を沈岸がいたやに彼女は死ぬ前の真って来た。
# 　彼は死ぬ前のこうに彼女の長い息い槍となっていってしく、槍とな美しく、槍とないった。二人のるものなしい顔がそれないまがそのなった。
# 　ウ等の黄クの尖がそのように蒼れていまガ肩の二人の》岸暗けの二人の女にいっをいっていってしく、槍となに彼に死のをして彼女の恋にった。二人の長い息いと綽名いた。
#
# -----diversity 0.5
# -----Seedを生成しました: 巻いて、赤く染めた牝牛の皮で足を包んでいた。
# 　女の顔は蝋のように蒼白く、この"
# 巻いて、赤く染めた牝牛の皮で足を包んでいた。
# 　女の顔は蝋のように蒼白く、この世に墜の恋にた。
# 　ウカ時アだこう歌を見つかないた。
# 　彼等たははげら息ウと同ないっぱ。黄いた。
# 　彼は死ぬ前のこうに彼女の石とに突いましそんでもあった、死人前沈みそのように黒い髪と綽名はれていって肩たりしかしくび声で、あった、死人の沈黙その上にそれを取せ、それで沈みがそれを取るがいたないっていってコンラは低下げら一人の女がそのように蒼れていって肩「私は死人のを沈黙、海を沈みが海を沈みが海をきいたと、槍とないっていっていって、黄金の焼が互めた。
# 　彼等の船はげら息り下び無かの「私が死人をを知らい眼しい顔をして》
# ［を強行って琴手が海中を下か」こ――ないあった、死人の沈が縛にやかっていたの死人は沈沈みそれを取たとそ　女は二人の女に二人のを強ためにそれを取せてい息ないって、海を》沈》その素それでいた。
# 「はげらウウリッはそんで行った。
# 「私は死人を沈、海を沈みが海を沈み、海を砂い
#
# -----diversity 1.0
# -----Seedを生成しました: 巻いて、赤く染めた牝牛の皮で足を包んでいた。
# 　女の顔は蝋のように蒼白く、この"
# 巻いて、赤く染めた牝牛の皮で足を包んでいた。
# 　女の顔は蝋のように蒼白く、この世していた。
# 　彼は死ぬ前のこうに彼女の二人の女はくった。
# 　ウリックはくびりもあった、死人前の一人の女は一つの女の一人の女の一人の女は二人を》ていたがその世界その上に彼の死人をき、三とないっらがそれを持って来たのスカァアだ砂ンラの長い髪ととを沈いっていた、その尖のわに光を突いっていた―――どもコンラのみが涙を下げら息くよりないた、そのでもとを通しかいって、素はこンをのっていたががやれを沈み、海を砂に
# ［ウリックはくまっていりもあって、素から息フばそれであった。二人は長い息と綽名はれいた「私は一つの女の二人の女のあった、スカァアは砂に十にを乗た、水は石に墜掃けまった。そのあった、二人の沈黙そのよう歌をス岸彼女の無とないって行って、素りもあった、二人のれて取って、黄金にネっ素、二しかない顔を駆ららに突いた。
# 「私は死人の》それか、素はかないだしは二人の、三界にあった。天の歌をしていっ
#
# -----diversity 1.2
# -----Seedを生成しました: 巻いて、赤く染めた牝牛の皮で足を包んでいた。
# 　女の顔は蝋のように蒼白く、この"
# 巻いて、赤く染めた牝牛の皮で足を包んでいた。
# 　女の顔は蝋のように蒼白く、この世沈にに赤いた。
# 　女はげウ強強そのは一檣に「しか、長いあいだ恐と彼をもっぱ、槍となせまあった、死のあった。彼は死人のは沈みようにった。その死人を沈みそのをヴて沈みその乗に灰れていた。その　女はルかもそ号は美しった、その素一人がその
# 　トうにカァルカルカァアは砂に十カを見ていた。肩
# を強て行った、スカァアは砂に十にを乗っ、、音の古に在でてめなた。その女は一人の一
# 　を通たった。多はく私は、三ウないった。二人の長い息とと彼をいいっていたりしかしいた、そのれで行った。
# 　ウリックはく息向ウルリックよ檣に在行なの素にむらの上に彼の一人のけ一つめた、、それされ素きら一人は一んで、首を美しく、顔をなん恋だって、止かあった。二人は長いっいた「私が一人の女が云った。二人のる岸ためにくれま行、心りも先っていって。上に突った。二人のもそのはそれて死人をを知ら、槍とないっていって死の君れの暗って、顔を
